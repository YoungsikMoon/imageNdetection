# %% [markdown]
# # 모델 저장하기

# %% [markdown]
# - 무엇을 저장해야 할까?
#     - 모델의 구조
#     - 모델의 weights

# %% [markdown]
# ## 훈련하는 동안 체크포인트 저장하기

# %%
import os

import tensorflow as tf
from tensorflow import keras

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_labels = train_labels[:1000]
test_labels = test_labels[:1000]

train_images = train_images[:1000].reshape(-1, 28 * 28) / 255.0
test_images = test_images[:1000].reshape(-1, 28 * 28) / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# 단순한 모델 정의
def create_model():
    model = tf.keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(784,)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10)
    ])

    model.compile(optimizer='adam',
                loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

    return model

# %%
model = create_model()

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 407050 (1.55 MB)
# Trainable params: 407050 (1.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### 체크포인트 콜백 사용하기

# %%
# 체크포인트 파일 경로 설정
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path) # 현재 경로 폴더 반환
checkpoint_dir
# Out:
# 'training_1'

# %%
# 모델의 가중치를 저장하는 체크포인트 콜백 선언
ckpt = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

model.fit(train_images,
          train_labels,
          epochs=10,
          validation_data=(test_images,test_labels),
          callbacks=[ckpt])  # 콜백 전달
# Out:
# Epoch 1/10
# 26/32 [=======================>......] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 1: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4192 - val_accuracy: 0.8750
# Epoch 2/10
# 31/32 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 2: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4325 - val_accuracy: 0.8710
# Epoch 3/10
# 28/32 [=========================>....] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 3: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4304 - val_accuracy: 0.8690
# Epoch 4/10
# 31/32 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 4: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4284 - val_accuracy: 0.8740
# Epoch 5/10
# 31/32 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 5: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4336 - val_accuracy: 0.8700
# Epoch 6/10
# 29/32 [==========================>...] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 6: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4259 - val_accuracy: 0.8730
# Epoch 7/10
# 27/32 [========================>.....] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 7: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4262 - val_accuracy: 0.8700
# Epoch 8/10
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 8: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4322 - val_accuracy: 0.8750
# Epoch 9/10
# 31/32 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 9: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4384 - val_accuracy: 0.8760
# Epoch 10/10
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 10: saving model to training_1/cp.ckpt
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4480 - val_accuracy: 0.8680

# %%
os.listdir(checkpoint_dir)
# Out:
# ['checkpoint', 'cp.ckpt.index', 'cp.ckpt.data-00000-of-00001']

# %% [markdown]
#  텐서플로 체크포인트 파일을 만들고 에포크가 종료될 때마다 업데이트합니다
#  - 아키텍처가 동일한 모델 간에는 가중치를 공유 가능
#
#  - 그렇다면, 원래 모델과 동일한 아키텍처를 가진 모델을 만든 다음 체크포인트 부여해보자.

# %%
# 동일한 아키텍처를 가진 모델 선언
model = create_model()

# 체크포인트 주지말고, 한번 평가해보자.
loss, acc = model.evaluate(test_images,  test_labels, verbose=2)
print("훈련되지 않은 모델의 정확도: {:5.2f}%".format(100*acc))
# Out:
# 32/32 - 0s - loss: 2.3045 - accuracy: 0.1060 - 291ms/epoch - 9ms/step
# 훈련되지 않은 모델의 정확도: 10.60%

# %% [markdown]
# 허접하다.

# %%
# 체크포인트에서 가중치를 로드하고 평가해보자.
model.load_weights(checkpoint_path)

loss,acc = model.evaluate(test_images,  test_labels, verbose=2)
print("복원된 모델의 정확도: {:5.2f}%".format(100*acc))
# Out:
# 32/32 - 0s - loss: 0.4196 - accuracy: 0.8740 - 91ms/epoch - 3ms/step
# 복원된 모델의 정확도: 87.40%

# %%
# format 리뷰
'온도 : {t:05d}도, 나이 : {a:03d}세'.format(t=10, a=13)

t=10
a=13
f'온도 : {t:05d}도, 나이 : {a:03d}세'
# Out:
# '온도 : 00010도, 나이 : 013세'

# %%
'{epoch:04d}, {batch:04d}'.format(batch=8, epoch=1)


batch=8
epoch=1
f'{epoch:04d}, {batch:04d}'
# Out:
# '0001, 0008'

# %%
# 파일 이름에 epoch 값 부여 (format 형식)
checkpoint_path = "training_2-1/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %% [markdown]
# - 체크포인트 주요 파라미터

# %%
ckpt = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, # 고유한 파일이름 부여 가능
    monitor='val_loss', # val_loss값을 기준으로 최저점일때를 기록하고 싶다면
    save_best_only=True, # True를 주면 monitor기준 최고상태 기록
    save_weights_only=True, # False면 모델 레이어 및 weight값 모두
    # save_freq=5 # 체크포인트 저장하는 주기 설정 가능 ('epoch'=에폭마다, 숫자=해당 배치마다)
    )

# %%
# 새로운 모델 객체를 만듭니다
model = create_model()

# %%
model.fit(train_images,
          train_labels,
          epochs=50,
          callbacks=[ckpt], # 체크포인트 부여
          validation_data=(test_images,test_labels),
          verbose=1)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 1s 18ms/step - loss: 1.1529 - accuracy: 0.6780 - val_loss: 0.7073 - val_accuracy: 0.7920
# Epoch 2/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.4206 - accuracy: 0.8890 - val_loss: 0.5645 - val_accuracy: 0.8210
# Epoch 3/50
# 32/32 [==============================] - 0s 14ms/step - loss: 0.3035 - accuracy: 0.9160 - val_loss: 0.4775 - val_accuracy: 0.8530
# Epoch 4/50
# 32/32 [==============================] - 0s 14ms/step - loss: 0.2022 - accuracy: 0.9520 - val_loss: 0.4437 - val_accuracy: 0.8590
# Epoch 5/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1544 - accuracy: 0.9670 - val_loss: 0.4427 - val_accuracy: 0.8550
# Epoch 6/50
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1161 - accuracy: 0.9770 - val_loss: 0.4123 - val_accuracy: 0.8670
# Epoch 7/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0943 - accuracy: 0.9860 - val_loss: 0.4242 - val_accuracy: 0.8650
# Epoch 8/50
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0734 - accuracy: 0.9930 - val_loss: 0.4300 - val_accuracy: 0.8620
# Epoch 9/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0486 - accuracy: 0.9980 - val_loss: 0.4246 - val_accuracy: 0.8620
# Epoch 10/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0339 - accuracy: 0.9990 - val_loss: 0.4318 - val_accuracy: 0.8690
# Epoch 11/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0298 - accuracy: 0.9990 - val_loss: 0.4007 - val_accuracy: 0.8670
# Epoch 12/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0294 - accuracy: 0.9990 - val_loss: 0.4222 - val_accuracy: 0.8710
# Epoch 13/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0214 - accuracy: 0.9990 - val_loss: 0.4207 - val_accuracy: 0.8680
# Epoch 14/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.4235 - val_accuracy: 0.8740
# Epoch 15/50
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.4309 - val_accuracy: 0.8700
# Epoch 16/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4273 - val_accuracy: 0.8690
# Epoch 17/50
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4265 - val_accuracy: 0.8720
# Epoch 18/50
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.4383 - val_accuracy: 0.8740
# Epoch 19/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.4351 - val_accuracy: 0.8760
# Epoch 20/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.4364 - val_accuracy: 0.8720
# Epoch 21/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.4360 - val_accuracy: 0.8720
# Epoch 22/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4408 - val_accuracy: 0.8740
# Epoch 23/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4428 - val_accuracy: 0.8770
# Epoch 24/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.4459 - val_accuracy: 0.8700
# Epoch 25/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4381 - val_accuracy: 0.8720
# Epoch 26/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4548 - val_accuracy: 0.8740
# Epoch 27/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4588 - val_accuracy: 0.8750
# Epoch 28/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4680 - val_accuracy: 0.8720
# Epoch 29/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4579 - val_accuracy: 0.8760
# Epoch 30/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4649 - val_accuracy: 0.8740
# Epoch 31/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4622 - val_accuracy: 0.8750
# Epoch 32/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4632 - val_accuracy: 0.8780
# Epoch 33/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4597 - val_accuracy: 0.8770
# Epoch 34/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4641 - val_accuracy: 0.8740
# Epoch 35/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4588 - val_accuracy: 0.8740
# Epoch 36/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4621 - val_accuracy: 0.8770
# Epoch 37/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4739 - val_accuracy: 0.8790
# Epoch 38/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4680 - val_accuracy: 0.8760
# Epoch 39/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4715 - val_accuracy: 0.8730
# Epoch 40/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4781 - val_accuracy: 0.8760
# Epoch 41/50
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4806 - val_accuracy: 0.8770
# Epoch 42/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4660 - val_accuracy: 0.8780
# Epoch 43/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4805 - val_accuracy: 0.8800
# Epoch 44/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4947 - val_accuracy: 0.8710
# Epoch 45/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4884 - val_accuracy: 0.8760
# Epoch 46/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4957 - val_accuracy: 0.8760
# Epoch 47/50
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4802 - val_accuracy: 0.8750
# Epoch 48/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4883 - val_accuracy: 0.8780
# Epoch 49/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4896 - val_accuracy: 0.8730
# Epoch 50/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4889 - val_accuracy: 0.8760

# %%
# 동일한 아키텍처를 가진 모델 선언
model = create_model()

# 체크포인트 주지말고, 한번 평가해보자.
loss, acc = model.evaluate(test_images,  test_labels, verbose=2)
print("훈련되지 않은 모델의 정확도: {:5.2f}%".format(100*acc))
# Out:
# 32/32 - 0s - loss: 2.3586 - accuracy: 0.0960 - 178ms/epoch - 6ms/step
# 훈련되지 않은 모델의 정확도:  9.60%

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest
# Out:
# 'training_2-1/cp-0010.ckpt'

# %%
model.load_weights(latest)

# 체크포인트 주지말고, 한번 평가해보자.
loss, acc = model.evaluate(test_images,  test_labels, verbose=2)
print("훈련되지 않은 모델의 정확도: {:5.2f}%".format(100*acc))
# Out:
# 32/32 - 0s - loss: 0.4030 - accuracy: 0.8760 - 54ms/epoch - 2ms/step
# 훈련되지 않은 모델의 정확도: 87.60%

# %%
### mytraining1 폴더에 저장
### best only로 저장, 최종 값만 저장되도록
### weight값만
checkpoint_path = "mytraining1/cp.ckpt"

ckpt = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, # 고유한 파일이름 부여 가능
    monitor='val_loss', # val_loss값을 기준으로 최저점일때를 기록하고 싶다면
    save_best_only=True, # True를 주면 monitor기준 최고상태 기록
    save_weights_only=True, # False면 모델 레이어 및 weight값 모두
    # save_freq=5 # 체크포인트 저장하는 에폭주기 설정 가능
    )

model = create_model()

model.fit(train_images,
          train_labels,
          epochs=50,
          callbacks=[ckpt], # 체크포인트 부여
          validation_data=(test_images,test_labels),
          verbose=1)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 1s 10ms/step - loss: 1.1894 - accuracy: 0.6400 - val_loss: 0.7003 - val_accuracy: 0.7880
# Epoch 2/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4381 - accuracy: 0.8760 - val_loss: 0.5384 - val_accuracy: 0.8320
# Epoch 3/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2949 - accuracy: 0.9220 - val_loss: 0.4733 - val_accuracy: 0.8480
# Epoch 4/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2026 - accuracy: 0.9580 - val_loss: 0.4738 - val_accuracy: 0.8460
# Epoch 5/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1658 - accuracy: 0.9660 - val_loss: 0.4176 - val_accuracy: 0.8640
# Epoch 6/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1245 - accuracy: 0.9750 - val_loss: 0.4186 - val_accuracy: 0.8650
# Epoch 7/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0908 - accuracy: 0.9850 - val_loss: 0.4120 - val_accuracy: 0.8650
# Epoch 8/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0688 - accuracy: 0.9910 - val_loss: 0.4083 - val_accuracy: 0.8640
# Epoch 9/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0528 - accuracy: 0.9960 - val_loss: 0.4105 - val_accuracy: 0.8670
# Epoch 10/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0408 - accuracy: 0.9970 - val_loss: 0.4098 - val_accuracy: 0.8680
# Epoch 11/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.4032 - val_accuracy: 0.8740
# Epoch 12/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0265 - accuracy: 0.9990 - val_loss: 0.4011 - val_accuracy: 0.8730
# Epoch 13/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.4032 - val_accuracy: 0.8750
# Epoch 14/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.4102 - val_accuracy: 0.8750
# Epoch 15/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.4162 - val_accuracy: 0.8760
# Epoch 16/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.4214 - val_accuracy: 0.8750
# Epoch 17/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.4109 - val_accuracy: 0.8770
# Epoch 18/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.4274 - val_accuracy: 0.8740
# Epoch 19/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.4235 - val_accuracy: 0.8710
# Epoch 20/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.4373 - val_accuracy: 0.8760
# Epoch 21/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4214 - val_accuracy: 0.8800
# Epoch 22/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4400 - val_accuracy: 0.8780
# Epoch 23/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4459 - val_accuracy: 0.8760
# Epoch 24/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4372 - val_accuracy: 0.8780
# Epoch 25/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4475 - val_accuracy: 0.8760
# Epoch 26/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4594 - val_accuracy: 0.8740
# Epoch 27/50
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4461 - val_accuracy: 0.8710
# Epoch 28/50
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4470 - val_accuracy: 0.8730
# Epoch 29/50
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4467 - val_accuracy: 0.8760
# Epoch 30/50
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4555 - val_accuracy: 0.8760
# Epoch 31/50
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4622 - val_accuracy: 0.8780
# Epoch 32/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4608 - val_accuracy: 0.8740
# Epoch 33/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4565 - val_accuracy: 0.8780
# Epoch 34/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4615 - val_accuracy: 0.8810
# Epoch 35/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4672 - val_accuracy: 0.8740
# Epoch 36/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4680 - val_accuracy: 0.8790
# Epoch 37/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4724 - val_accuracy: 0.8770
# Epoch 38/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4710 - val_accuracy: 0.8760
# Epoch 39/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4831 - val_accuracy: 0.8750
# Epoch 40/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4753 - val_accuracy: 0.8750
# Epoch 41/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4857 - val_accuracy: 0.8740
# Epoch 42/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4847 - val_accuracy: 0.8750
# Epoch 43/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4881 - val_accuracy: 0.8770
# Epoch 44/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4907 - val_accuracy: 0.8740
# Epoch 45/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4919 - val_accuracy: 0.8740
# Epoch 46/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4887 - val_accuracy: 0.8760
# Epoch 47/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4970 - val_accuracy: 0.8770
# Epoch 48/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4855 - val_accuracy: 0.8750
# Epoch 49/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4997 - val_accuracy: 0.8750
# Epoch 50/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4910 - val_accuracy: 0.8780

# %%
model.load_weights(checkpoint_path) # "mytraining1/cp.ckpt"

model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 32/32 - 0s - loss: 0.4011 - accuracy: 0.8730 - 60ms/epoch - 2ms/step
# [0.4011469781398773, 0.8730000257492065]

# %%
tf.keras.callbacks.ModelCheckpoint?

# %%
### mytraining2 폴더에 저장
### 5epoch마다 저장
### weight값만
checkpoint_path = "mytraining3/cp-{epoch:04d}.ckpt"

ckpt = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, # 고유한 파일이름 부여 가능
    monitor='val_loss', # val_loss값을 기준으로 최저점일때를 기록하고 싶다면
    save_best_only=False, # True를 주면 monitor기준 최고상태 기록
    save_weights_only=True, # False면 모델 레이어 및 weight값 모두
    period=5, # 체크포인트 저장하는 에폭주기 설정 가능
    save_freq='epoch' # epoch의 끝에서 저장할지 여부
    )
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
model = create_model()

model.fit(train_images,
          train_labels,
          epochs=50,
          callbacks=[ckpt], # 체크포인트 부여
          validation_data=(test_images,test_labels),
          verbose=1)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 1s 10ms/step - loss: 1.1696 - accuracy: 0.6700 - val_loss: 0.6972 - val_accuracy: 0.7960
# Epoch 2/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4279 - accuracy: 0.8800 - val_loss: 0.5532 - val_accuracy: 0.8220
# Epoch 3/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2945 - accuracy: 0.9280 - val_loss: 0.4978 - val_accuracy: 0.8440
# Epoch 4/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2044 - accuracy: 0.9520 - val_loss: 0.4376 - val_accuracy: 0.8610
# Epoch 5/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1516 - accuracy: 0.9660 - val_loss: 0.4292 - val_accuracy: 0.8570
# Epoch 6/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1184 - accuracy: 0.9790 - val_loss: 0.4565 - val_accuracy: 0.8520
# Epoch 7/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0852 - accuracy: 0.9860 - val_loss: 0.4116 - val_accuracy: 0.8610
# Epoch 8/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0685 - accuracy: 0.9950 - val_loss: 0.4302 - val_accuracy: 0.8560
# Epoch 9/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0549 - accuracy: 0.9940 - val_loss: 0.4030 - val_accuracy: 0.8660
# Epoch 10/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0451 - accuracy: 0.9980 - val_loss: 0.3989 - val_accuracy: 0.8720
# Epoch 11/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0323 - accuracy: 0.9990 - val_loss: 0.4035 - val_accuracy: 0.8690
# Epoch 12/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0312 - accuracy: 0.9990 - val_loss: 0.4311 - val_accuracy: 0.8620
# Epoch 13/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.4232 - val_accuracy: 0.8630
# Epoch 14/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.4316 - val_accuracy: 0.8640
# Epoch 15/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.4337 - val_accuracy: 0.8670
# Epoch 16/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.4475 - val_accuracy: 0.8570
# Epoch 17/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.4384 - val_accuracy: 0.8620
# Epoch 18/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.4303 - val_accuracy: 0.8710
# Epoch 19/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.4465 - val_accuracy: 0.8670
# Epoch 20/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.4366 - val_accuracy: 0.8700
# Epoch 21/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4387 - val_accuracy: 0.8730
# Epoch 22/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.4554 - val_accuracy: 0.8680
# Epoch 23/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4587 - val_accuracy: 0.8670
# Epoch 24/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4487 - val_accuracy: 0.8680
# Epoch 25/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4560 - val_accuracy: 0.8660
# Epoch 26/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4685 - val_accuracy: 0.8680
# Epoch 27/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4587 - val_accuracy: 0.8670
# Epoch 28/50
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4750 - val_accuracy: 0.8690
# Epoch 29/50
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4630 - val_accuracy: 0.8700
# Epoch 30/50
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4642 - val_accuracy: 0.8700
# Epoch 31/50
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4735 - val_accuracy: 0.8680
# Epoch 32/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4677 - val_accuracy: 0.8720
# Epoch 33/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.8730
# Epoch 34/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4773 - val_accuracy: 0.8700
# Epoch 35/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4751 - val_accuracy: 0.8730
# Epoch 36/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4754 - val_accuracy: 0.8730
# Epoch 37/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4836 - val_accuracy: 0.8700
# Epoch 38/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4834 - val_accuracy: 0.8710
# Epoch 39/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4851 - val_accuracy: 0.8720
# Epoch 40/50
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4777 - val_accuracy: 0.8710
# Epoch 41/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4909 - val_accuracy: 0.8720
# Epoch 42/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4814 - val_accuracy: 0.8730
# Epoch 43/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4852 - val_accuracy: 0.8710
# Epoch 44/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4866 - val_accuracy: 0.8750
# Epoch 45/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4881 - val_accuracy: 0.8720
# Epoch 46/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4898 - val_accuracy: 0.8760
# Epoch 47/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4904 - val_accuracy: 0.8730
# Epoch 48/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4965 - val_accuracy: 0.8740
# Epoch 49/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4938 - val_accuracy: 0.8750
# Epoch 50/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4977 - val_accuracy: 0.8760

# %% [markdown]
# ### early stopping & 체크포인트 같이 사용하기

# %%
checkpoint_path = "training_3/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
ckpt = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, # 고유한 파일이름 부여 가능
    monitor='val_loss', # val_loss값을 기준으로 최저점일때를 기록하고 싶다면
    save_best_only=True, # True를 주면 monitor기준 최고상태 기록
    save_weights_only=True, # False면 모델 레이어 및 weight값 모두
    # save_freq=5 # 체크포인트 저장하는 에폭주기 설정 가능
    )

# %%
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
# 새로운 모델 객체를 만듭니다
model = create_model()

# %%
model.fit(train_images,
          train_labels,
          epochs=100,
          callbacks=[ckpt, early], # 체크포인트 부여, early stopping
          validation_data=(test_images,test_labels),
          verbose=1)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 11ms/step - loss: 1.1548 - accuracy: 0.6690 - val_loss: 0.6944 - val_accuracy: 0.8090
# Epoch 2/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4264 - accuracy: 0.8800 - val_loss: 0.5109 - val_accuracy: 0.8440
# Epoch 3/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2856 - accuracy: 0.9220 - val_loss: 0.5143 - val_accuracy: 0.8380
# Epoch 4/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2094 - accuracy: 0.9590 - val_loss: 0.4553 - val_accuracy: 0.8540
# Epoch 5/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1528 - accuracy: 0.9700 - val_loss: 0.4860 - val_accuracy: 0.8440
# Epoch 6/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.1169 - accuracy: 0.9760 - val_loss: 0.4556 - val_accuracy: 0.8430
# Epoch 7/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0869 - accuracy: 0.9820 - val_loss: 0.4052 - val_accuracy: 0.8600
# Epoch 8/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0645 - accuracy: 0.9920 - val_loss: 0.4288 - val_accuracy: 0.8590
# Epoch 9/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0475 - accuracy: 0.9970 - val_loss: 0.4310 - val_accuracy: 0.8610
# Epoch 10/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0374 - accuracy: 0.9990 - val_loss: 0.4217 - val_accuracy: 0.8690

# %% [markdown]
# ### 직접 가중치 체크포인트 저장

# %%
# 가중치 저장
model.save_weights('./checkpoints/my_checkpoint.ckpt')

model = create_model()

# 가중치 복원
model.load_weights('./checkpoints/my_checkpoint.ckpt')

loss,acc = model.evaluate(test_images,  test_labels, verbose=2)
print("복원된 모델의 정확도: {:5.2f}%".format(100*acc))
# Out:
# 32/32 - 0s - loss: 0.4217 - accuracy: 0.8690 - 187ms/epoch - 6ms/step
# 복원된 모델의 정확도: 86.90%

# %% [markdown]
# ## 전체 모델 저장(모델레이어와 함께 저장)
# 1) save_weights_only=False 로 변경
# 2) 직접 model.save() : SavedModel(pb)
# 3) HDF5 파일로 저장하기

# %% [markdown]
# ### save_weights_only=False 로 변경

# %%
checkpoint_path = "training_4/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
ckpt = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, # 고유한 파일이름 부여 가능
    monitor='val_loss', # val_loss값을 기준으로 최저점일때를 기록하고 싶다면
    save_best_only=True, # True를 주면 monitor기준 최고상태 기록
    save_weights_only=False, # False면 모델 레이어 및 weight값 모두
    # save_freq=5 # 체크포인트 저장하는 에폭주기 설정 가능
    )

# %%
# 새로운 모델 객체를 만듭니다
model = create_model()

# %%
model.fit(train_images,
          train_labels,
          epochs=1,
          callbacks=[ckpt], # 체크포인트 부여
          validation_data=(test_images,test_labels),
          verbose=1)
# Out:
# 32/32 [==============================] - 2s 57ms/step - loss: 1.1098 - accuracy: 0.6830 - val_loss: 0.6955 - val_accuracy: 0.7770

# %% [markdown]
# ### SavedModel(pb)
# SavedModel 형식은 protobuf 바이너리와 TensorFlow 체크포인트를 포함

# %%
# 새로운 모델 객체를 만들고 훈련합니다
model = create_model()
model.fit(train_images, train_labels, epochs=5)

# SavedModel로 전체 모델을 저장합니다
# !mkdir -p saved_model
model.save('saved_model/my_model')
# Out:
# Epoch 1/5
# 32/32 [==============================] - 1s 8ms/step - loss: 1.1119 - accuracy: 0.6820
# Epoch 2/5
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3919 - accuracy: 0.8950
# Epoch 3/5
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2897 - accuracy: 0.9280
# Epoch 4/5
# 32/32 [==============================] - 0s 8ms/step - loss: 0.2022 - accuracy: 0.9500
# Epoch 5/5
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1533 - accuracy: 0.9670

# %%
# my_model 디렉토리
# !ls saved_model
# Out:
# my_model

# %%
# assests 폴더, saved_model.pb, variables 폴더
# !ls saved_model/my_model
# Out:
# assets	fingerprint.pb	keras_metadata.pb  saved_model.pb  variables

# %%
new_model = tf.keras.models.load_model('saved_model/my_model')

# 모델 구조를 확인합니다
new_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 512)               401920
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_19 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 407050 (1.55 MB)
# Trainable params: 407050 (1.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 복원된 모델은 원본 모델과 동일한 매개변수로 컴파일되어 있습니다. 이 모델을 평가하고 예측에 사용해 보죠:

# %%
# 복원된 모델을 평가합니다
loss, acc = new_model.evaluate(test_images,  test_labels, verbose=2)
print('복원된 모델의 정확도: {:5.2f}%'.format(100*acc))

print(new_model.predict(test_images).shape)
# Out:
# 32/32 - 0s - loss: 0.4168 - accuracy: 0.8580 - 203ms/epoch - 6ms/step
# 복원된 모델의 정확도: 85.80%
# 32/32 [==============================] - 0s 2ms/step
# (1000, 10)

# %% [markdown]
# ### HDF5 파일로 저장하기
# 케라스는 HDF5 표준을 따르는 기본 저장 포맷을 제공합니다.

# %%
# 새로운 모델 객체를 만들고 훈련합니다
model = create_model()
model.fit(train_images, train_labels, epochs=5)

# 전체 모델을 HDF5 파일로 저장합니다
# '.h5' 확장자는 이 모델이 HDF5로 저장되었다는 것을 나타냅니다
model.save('my_model.h5')
# Out:
# Epoch 1/5
# 32/32 [==============================] - 1s 8ms/step - loss: 1.2097 - accuracy: 0.6540
# Epoch 2/5
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4401 - accuracy: 0.8800
# Epoch 3/5
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2898 - accuracy: 0.9230
# Epoch 4/5
# 32/32 [==============================] - 0s 8ms/step - loss: 0.2194 - accuracy: 0.9460
# Epoch 5/5
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1620 - accuracy: 0.9660
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### h5 VS pb
# - 공통점 : 레이어 & 가중치 모두 저장
# - 차이점
# 1) HDF5 : 객체 구성을 사용하여 모델 아키텍처를 저장
# 2) SavedModel : 실행 그래프를 저장. 원본 코드 없이도 사용자 지정 객체를 저장 가능

# %% [markdown]
# #### h5 to pb 변환하기

# %%
# !mkdir converted

# %%
model = tf.keras.models.load_model('my_model.h5')

# %%
export_path = 'converted'
model.save(export_path, save_format="tf")

# %% [markdown]
# ### 과제
# 아래 조건에 맞춰 콜백을 이용하여 cifar 10 데이터를 resnet 50으로 학습을 시켜봅시다.
#
# - early stopping : 50 에폭을 잡고, val loss 가 더이상 개선되지 않을 때 조기 종료 (세부 설정은 자율적으로 설정)
# - model save : weights만 저장 (세부 설정을 자율)
#
# 학습이 완료되면, 저장된 weights를 불러와서 검증해봅시다.
